# %%
# %load util.py
"""MLT: Utility code."""

import os
import pandas as pd
import matplotlib.pyplot as plt

def symbol_to_path(symbol, base_dir=os.path.join("..", "data")):
    """Return CSV file path given ticker symbol."""
    return os.path.join(base_dir, "{}.csv".format(str(symbol)))


def get_data(symbols, dates, addSPY=True):
    """Read stock data (adjusted close) for given symbols from CSV files."""
    df = pd.DataFrame(index=dates)
    if addSPY and 'SPY' not in symbols:  # add SPY for reference, if absent
        symbols = ['SPY'] + symbols

    for symbol in symbols:
        df_temp = pd.read_csv(symbol_to_path(symbol), index_col='Date',
                parse_dates=True, usecols=['Date', 'Adj Close'], na_values=['nan'])
        df_temp = df_temp.rename(columns={'Adj Close': symbol})
        df = df.join(df_temp)
        if symbol == 'SPY':  # drop dates SPY did not trade
            df = df.dropna(subset=["SPY"])

    return df


def plot_data(df, title="Stock prices", xlabel="Date", ylabel="Price"):
    """Plot stock prices with a custom title and meaningful axis labels."""
    ax = df.plot(title=title, fontsize=12)
    ax.set_xlabel(xlabel)
    ax.set_ylabel(ylabel)
    plt.show()

# %%
import matplotlib.pyplot as plt
orders_file = "./orders/orders-01.csv"
orders_df = pd.read_csv(orders_file, index_col='Date', parse_dates=True, na_values=['nan'])
orders_df = orders_df.sort_index()
orderdates = orders_df.index.unique()
start_date = orders_df.index[0] 
end_date = orders_df.index[-1]
symbols = orders_df['Symbol'].unique().tolist()
dates = pd.date_range(start_date, end_date)
prices = get_data(symbols, dates)
print "##########Days in price:     ", len(prices.index)
#plot_data(prices)
symbols.append('cash')
portvals = pd.DataFrame(data = np.zeros((prices.index.size, len(symbols))), index = prices.index, columns=symbols)
print "##########Days in portvals:     ", len(portvals.index)
#plot_data(portvals)
DATES = prices.index.to_datetime()
portvals['cash'] = 1000000
for i, odate in enumerate(orderdates):
    orders = orders_df[odate:odate]
    temp = portvals[odate:odate].copy()
    print "before transaction------------"
    print "temp"
    print temp
    print "price"
    print prices[odate:odate]
    print "orders"
    print orders
    for j in range(orders.shape[0]):
        if orders.ix[j]['Order'] == 'BUY':
            temp[orders.ix[j]['Symbol']] += orders.ix[j]['Shares']
            temp['cash'] -= orders.ix[j]['Shares'] * prices.ix[odate][orders.ix[j]['Symbol']]
        else:
            temp[orders.ix[j]['Symbol']] -= orders.ix[j]['Shares']
            temp['cash'] += orders.ix[j]['Shares'] * prices.ix[odate][orders.ix[j]['Symbol']]
        longs = temp.ix[0][np.where(temp.ix[0] > 0)[0]].keys().tolist()
        if 'cash' in longs:
            longs.remove('cash')
        print "longs:             ", longs
        shorts = temp.ix[0][np.where(temp.ix[0] < 0)[0]].keys().tolist()
        if 'cash' in shorts:
            shorts.remove('cash')
        print "shorts:             ",shorts 
    print "temp: after transaction++++++++++++"
    print temp
    
    if len(longs) > 0:
        print "temp[longs]"
        print temp[longs]
        print "prices[longs]"
        print prices[odate:odate][longs]
        print "Product"
        print prices[odate:odate][longs]*temp[longs]
        print "Sum"
        print np.sum(prices[odate:odate][longs]*temp[longs])
        longsum = np.sum(prices[odate:odate][longs]*temp[longs]).values[0]
    else:
        longsum = 0
    if len(shorts) > 0:
        print "temp[shorts]"
        print temp[shorts]
        print "prices[shorts]"
        print prices[odate:odate][shorts]
        print "Product"
        print prices[odate:odate][shorts]*temp[shorts]
        print "Sum"
        print np.sum(prices[odate:odate][shorts]*temp[shorts])
        shortsum = np.abs(np.sum(prices[odate:odate][shorts]*temp[shorts])).values[0]
    else:
        shortsum = 0
    print 'temp[cash]'
    print temp['cash']
    leverage = (longsum + shortsum)/(longsum - shortsum + temp['cash'].values[0] ) 
    print "leverage: xxxxxxxxxxxxxxxxx"
    print leverage
    print 
    print 
    print 
    
    
    if leverage <= 2.0:
        td = np.where(DATES >= orderdates[i])[0].size
        portvals[orderdates[i]:] = np.repeat(temp.values, td, axis = 0 ) 
symbols.remove('cash')
print symbols
plot_data(portvals[symbols])
plot_data(prices[symbols])
print portvals[symbols]
print "============================================================================"
print prices[symbols]
tv = np.sum(portvals[symbols]*prices[symbols], axis = 1) + portvals['cash']
plot_data(tv)
# Out:
# ##########Days in price:      245
# ##########Days in portvals:      245
# before transaction------------
# temp
#             AAPL  IBM  GOOG  XOM     cash
# 2011-01-10   0.0  0.0   0.0  0.0  1000000
# price
#                SPY    AAPL     IBM    GOOG    XOM
# 2011-01-10  123.19  340.99  143.41  614.21  72.02
# orders
#            Symbol Order  Shares
# Date
# 2011-01-10   AAPL   BUY    1500
# longs:              ['AAPL']
# shorts:              []
# temp: after transaction++++++++++++
#               AAPL  IBM  GOOG  XOM      cash
# 2011-01-10  1500.0  0.0   0.0  0.0  488515.0
# temp[longs]
#               AAPL
# 2011-01-10  1500.0
# prices[longs]
#               AAPL
# 2011-01-10  340.99
# Product
#                 AAPL
# 2011-01-10  511485.0
# Sum
# AAPL    511485.0
# dtype: float64
# temp[cash]
# 2011-01-10    488515.0
# Name: cash, dtype: float64
# leverage: xxxxxxxxxxxxxxxxx
# 0.511485
#
#
#
# before transaction------------
# temp
#               AAPL  IBM  GOOG  XOM      cash
# 2011-01-13  1500.0  0.0   0.0  0.0  488515.0
# price
#                SPY   AAPL     IBM    GOOG    XOM
# 2011-01-13  124.54  344.2  144.55  616.69  73.54
# orders
#            Symbol Order  Shares
# Date
# 2011-01-13   AAPL  SELL    1500
# 2011-01-13    IBM   BUY    4000
# longs:              []
# shorts:              []
# longs:              ['IBM']
# shorts:              []
# temp: after transaction++++++++++++
#             AAPL     IBM  GOOG  XOM      cash
# 2011-01-13   0.0  4000.0   0.0  0.0  426615.0
# temp[longs]
#                IBM
# 2011-01-13  4000.0
# prices[longs]
#                IBM
# 2011-01-13  144.55
# Product
#                  IBM
# 2011-01-13  578200.0
# Sum
# IBM    578200.0
# dtype: float64
# temp[cash]
# 2011-01-13    426615.0
# Name: cash, dtype: float64
# leverage: xxxxxxxxxxxxxxxxx
# 0.575429307883
#
#
#
# before transaction------------
# temp
#             AAPL     IBM  GOOG  XOM      cash
# 2011-01-26   0.0  4000.0   0.0  0.0  426615.0
# price
#               SPY    AAPL     IBM   GOOG    XOM
# 2011-01-26  125.8  342.38  156.42  616.5  76.37
# orders
#            Symbol Order  Shares
# Date
# 2011-01-26   GOOG   BUY    1000
# longs:              ['IBM', 'GOOG']
# shorts:              []
# temp: after transaction++++++++++++
#             AAPL     IBM    GOOG  XOM      cash
# 2011-01-26   0.0  4000.0  1000.0  0.0 -189885.0
# temp[longs]
#                IBM    GOOG
# 2011-01-26  4000.0  1000.0
# prices[longs]
#                IBM   GOOG
# 2011-01-26  156.42  616.5
# Product
#                  IBM      GOOG
# 2011-01-26  625680.0  616500.0
# Sum
# IBM     625680.0
# GOOG    616500.0
# dtype: float64
# temp[cash]
# 2011-01-26   -189885.0
# Name: cash, dtype: float64
# leverage: xxxxxxxxxxxxxxxxx
# 1.43572092383
#
#
#
# before transaction------------
# temp
#             AAPL     IBM    GOOG  XOM      cash
# 2011-02-02   0.0  4000.0  1000.0  0.0 -189885.0
# price
#               SPY    AAPL     IBM   GOOG    XOM
# 2011-02-02  126.6  342.85  158.62  612.0  79.96
# orders
#            Symbol Order  Shares
# Date
# 2011-02-02    XOM  SELL    4000
# longs:              ['IBM', 'GOOG']
# shorts:              ['XOM']
# temp: after transaction++++++++++++
#             AAPL     IBM    GOOG     XOM      cash
# 2011-02-02   0.0  4000.0  1000.0 -4000.0  129955.0
# temp[longs]
#                IBM    GOOG
# 2011-02-02  4000.0  1000.0
# prices[longs]
#                IBM   GOOG
# 2011-02-02  158.62  612.0
# Product
#                  IBM      GOOG
# 2011-02-02  634480.0  612000.0
# Sum
# IBM     634480.0
# GOOG    612000.0
# dtype: float64
# temp[shorts]
#                XOM
# 2011-02-02 -4000.0
# prices[shorts]
#               XOM
# 2011-02-02  79.96
# Product
#                  XOM
# 2011-02-02 -319840.0
# Sum
# XOM   -319840.0
# dtype: float64
# temp[cash]
# 2011-02-02    129955.0
# Name: cash, dtype: float64
# leverage: xxxxxxxxxxxxxxxxx
# 2.14649287554
#
#
#
# before transaction------------
# temp
#             AAPL     IBM    GOOG  XOM      cash
# 2011-02-10   0.0  4000.0  1000.0  0.0 -189885.0
# price
#                SPY    AAPL     IBM    GOOG    XOM
# 2011-02-10  128.37  353.02  160.02  616.44  80.18
# orders
#            Symbol Order  Shares
# Date
# 2011-02-10    XOM   BUY    4000
# longs:              ['IBM', 'GOOG', 'XOM']
# shorts:              []
# temp: after transaction++++++++++++
#             AAPL     IBM    GOOG     XOM      cash
# 2011-02-10   0.0  4000.0  1000.0  4000.0 -510605.0
# temp[longs]
#                IBM    GOOG     XOM
# 2011-02-10  4000.0  1000.0  4000.0
# prices[longs]
#                IBM    GOOG    XOM
# 2011-02-10  160.02  616.44  80.18
# Product
#                  IBM      GOOG       XOM
# 2011-02-10  640080.0  616440.0  320720.0
# Sum
# IBM     640080.0
# GOOG    616440.0
# XOM     320720.0
# dtype: float64
# temp[cash]
# 2011-02-10   -510605.0
# Name: cash, dtype: float64
# leverage: xxxxxxxxxxxxxxxxx
# 4.94365707666
#
#
#
# before transaction------------
# temp
#             AAPL     IBM    GOOG  XOM      cash
# 2011-03-03   0.0  4000.0  1000.0  0.0 -189885.0
# price
#                SPY    AAPL     IBM    GOOG   XOM
# 2011-03-03  129.49  358.02  159.42  609.56  82.7
# orders
#            Symbol Order  Shares
# Date
# 2011-03-03   GOOG  SELL    1000
# 2011-03-03   GOOG  SELL    2200
# longs:              ['IBM']
# shorts:              []
# longs:              ['IBM']
# shorts:              ['GOOG']
# temp: after transaction++++++++++++
#             AAPL     IBM    GOOG  XOM       cash
# 2011-03-03   0.0  4000.0 -2200.0  0.0  1760707.0
# temp[longs]
#                IBM
# 2011-03-03  4000.0
# prices[longs]
#                IBM
# 2011-03-03  159.42
# Product
#                  IBM
# 2011-03-03  637680.0
# Sum
# IBM    637680.0
# dtype: float64
# temp[shorts]
#               GOOG
# 2011-03-03 -2200.0
# prices[shorts]
#               GOOG
# 2011-03-03  609.56
# Product
#                  GOOG
# 2011-03-03 -1341032.0
# Sum
# GOOG   -1341032.0
# dtype: float64
# temp[cash]
# 2011-03-03    1760707.0
# Name: cash, dtype: float64
# leverage: xxxxxxxxxxxxxxxxx
# 1.87137905434
#
#
#
# before transaction------------
# temp
#             AAPL     IBM    GOOG  XOM       cash
# 2011-05-03   0.0  4000.0 -2200.0  0.0  1760707.0
# price
#                SPY    AAPL     IBM    GOOG    XOM
# 2011-05-03  132.25  346.71  168.58  533.89  82.51
# orders
#            Symbol Order  Shares
# Date
# 2011-05-03    IBM   BUY    1500
# longs:              ['IBM']
# shorts:              ['GOOG']
# temp: after transaction++++++++++++
#             AAPL     IBM    GOOG  XOM       cash
# 2011-05-03   0.0  5500.0 -2200.0  0.0  1507837.0
# temp[longs]
#                IBM
# 2011-05-03  5500.0
# prices[longs]
#                IBM
# 2011-05-03  168.58
# Product
#                  IBM
# 2011-05-03  927190.0
# Sum
# IBM    927190.0
# dtype: float64
# temp[shorts]
#               GOOG
# 2011-05-03 -2200.0
# prices[shorts]
#               GOOG
# 2011-05-03  533.89
# Product
#                  GOOG
# 2011-05-03 -1174558.0
# Sum
# GOOG   -1174558.0
# dtype: float64
# temp[cash]
# 2011-05-03    1507837.0
# Name: cash, dtype: float64
# leverage: xxxxxxxxxxxxxxxxx
# 1.66743331252
#
#
#
# before transaction------------
# temp
#             AAPL     IBM    GOOG  XOM       cash
# 2011-06-03   0.0  5500.0 -2200.0  0.0  1507837.0
# price
#                SPY    AAPL     IBM    GOOG    XOM
# 2011-06-03  127.08  341.97  161.67  523.08  78.68
# orders
#            Symbol Order  Shares
# Date
# 2011-06-03    IBM  SELL    3300
# longs:              ['IBM']
# shorts:              ['GOOG']
# temp: after transaction++++++++++++
#             AAPL     IBM    GOOG  XOM       cash
# 2011-06-03   0.0  2200.0 -2200.0  0.0  2041348.0
# temp[longs]
#                IBM
# 2011-06-03  2200.0
# prices[longs]
#                IBM
# 2011-06-03  161.67
# Product
#                  IBM
# 2011-06-03  355674.0
# Sum
# IBM    355674.0
# dtype: float64
# temp[shorts]
#               GOOG
# 2011-06-03 -2200.0
# prices[shorts]
#               GOOG
# 2011-06-03  523.08
# Product
#                  GOOG
# 2011-06-03 -1150776.0
# Sum
# GOOG   -1150776.0
# dtype: float64
# temp[cash]
# 2011-06-03    2041348.0
# Name: cash, dtype: float64
# leverage: xxxxxxxxxxxxxxxxx
# 1.20879023885
#
#
#
# before transaction------------
# temp
#             AAPL     IBM    GOOG  XOM       cash
# 2011-06-10   0.0  2200.0 -2200.0  0.0  2041348.0
# price
#                SPY    AAPL     IBM    GOOG    XOM
# 2011-06-10  124.33  324.51  159.84  509.51  77.32
# orders
#            Symbol Order  Shares
# Date
# 2011-06-10   AAPL   BUY    1200
# longs:              ['AAPL', 'IBM']
# shorts:              ['GOOG']
# temp: after transaction++++++++++++
#               AAPL     IBM    GOOG  XOM       cash
# 2011-06-10  1200.0  2200.0 -2200.0  0.0  1651936.0
# temp[longs]
#               AAPL     IBM
# 2011-06-10  1200.0  2200.0
# prices[longs]
#               AAPL     IBM
# 2011-06-10  324.51  159.84
# Product
#                 AAPL       IBM
# 2011-06-10  389412.0  351648.0
# Sum
# AAPL    389412.0
# IBM     351648.0
# dtype: float64
# temp[shorts]
#               GOOG
# 2011-06-10 -2200.0
# prices[shorts]
#               GOOG
# 2011-06-10  509.51
# Product
#                  GOOG
# 2011-06-10 -1120922.0
# Sum
# GOOG   -1120922.0
# dtype: float64
# temp[cash]
# 2011-06-10    1651936.0
# Name: cash, dtype: float64
# leverage: xxxxxxxxxxxxxxxxx
# 1.64090757975
#
#
#
# before transaction------------
# temp
#               AAPL     IBM    GOOG  XOM       cash
# 2011-08-01  1200.0  2200.0 -2200.0  0.0  1651936.0
# price
#               SPY    AAPL     IBM    GOOG    XOM
# 2011-08-01  126.1  395.05  177.05  606.77  77.15
# orders
#            Symbol Order  Shares
# Date
# 2011-08-01   GOOG   BUY      55
# 2011-08-01   GOOG  SELL      55
# longs:              ['AAPL', 'IBM']
# shorts:              ['GOOG']
# longs:              ['AAPL', 'IBM']
# shorts:              ['GOOG']
# temp: after transaction++++++++++++
#               AAPL     IBM    GOOG  XOM       cash
# 2011-08-01  1200.0  2200.0 -2200.0  0.0  1651936.0
# temp[longs]
#               AAPL     IBM
# 2011-08-01  1200.0  2200.0
# prices[longs]
#               AAPL     IBM
# 2011-08-01  395.05  177.05
# Product
#                 AAPL       IBM
# 2011-08-01  474060.0  389510.0
# Sum
# AAPL    474060.0
# IBM     389510.0
# dtype: float64
# temp[shorts]
#               GOOG
# 2011-08-01 -2200.0
# prices[shorts]
#               GOOG
# 2011-08-01  606.77
# Product
#                  GOOG
# 2011-08-01 -1334894.0
# Sum
# GOOG   -1334894.0
# dtype: float64
# temp[cash]
# 2011-08-01    1651936.0
# Name: cash, dtype: float64
# leverage: xxxxxxxxxxxxxxxxx
# 2.28662549204
#
#
#
# before transaction------------
# temp
#               AAPL     IBM    GOOG  XOM       cash
# 2011-12-20  1200.0  2200.0 -2200.0  0.0  1651936.0
# price
#                SPY    AAPL     IBM    GOOG    XOM
# 2011-12-20  122.75  394.26  184.95  630.37  80.47
# orders
#            Symbol Order  Shares
# Date
# 2011-12-20   AAPL  SELL    1200
# longs:              ['IBM']
# shorts:              ['GOOG']
# temp: after transaction++++++++++++
#             AAPL     IBM    GOOG  XOM       cash
# 2011-12-20   0.0  2200.0 -2200.0  0.0  2125048.0
# temp[longs]
#                IBM
# 2011-12-20  2200.0
# prices[longs]
#                IBM
# 2011-12-20  184.95
# Product
#                  IBM
# 2011-12-20  406890.0
# Sum
# IBM    406890.0
# dtype: float64
# temp[shorts]
#               GOOG
# 2011-12-20 -2200.0
# prices[shorts]
#               GOOG
# 2011-12-20  630.37
# Product
#                  GOOG
# 2011-12-20 -1386814.0
# Sum
# GOOG   -1386814.0
# dtype: float64
# temp[cash]
# 2011-12-20    2125048.0
# Name: cash, dtype: float64
# leverage: xxxxxxxxxxxxxxxxx
# 1.56638407718
#
#
#
# before transaction------------
# temp
#             AAPL     IBM    GOOG  XOM       cash
# 2011-12-21   0.0  2200.0 -2200.0  0.0  2125048.0
# price
#                SPY    AAPL     IBM    GOOG    XOM
# 2011-12-21  122.99  394.76  179.25  625.82  81.57
# orders
#            Symbol Order  Shares
# Date
# 2011-12-21   AAPL   BUY      20
# longs:              ['AAPL', 'IBM']
# shorts:              ['GOOG']
# temp: after transaction++++++++++++
#             AAPL     IBM    GOOG  XOM       cash
# 2011-12-21  20.0  2200.0 -2200.0  0.0  2117152.8
# temp[longs]
#             AAPL     IBM
# 2011-12-21  20.0  2200.0
# prices[longs]
#               AAPL     IBM
# 2011-12-21  394.76  179.25
# Product
#               AAPL       IBM
# 2011-12-21  7895.2  394350.0
# Sum
# AAPL      7895.2
# IBM     394350.0
# dtype: float64
# temp[shorts]
#               GOOG
# 2011-12-21 -2200.0
# prices[shorts]
#               GOOG
# 2011-12-21  625.82
# Product
#                  GOOG
# 2011-12-21 -1376804.0
# Sum
# GOOG   -1376804.0
# dtype: float64
# temp[cash]
# 2011-12-21    2117152.8
# Name: cash, dtype: float64
# leverage: xxxxxxxxxxxxxxxxx
# 1.85059846788
#
#
#
# before transaction------------
# temp
#             AAPL     IBM    GOOG  XOM       cash
# 2011-12-27  20.0  2200.0 -2200.0  0.0  2117152.8
# price
#                SPY    AAPL     IBM    GOOG    XOM
# 2011-12-27  125.29  404.79  182.68  640.25  83.69
# orders
#            Symbol Order  Shares
# Date
# 2011-12-27   GOOG   BUY    2200
# longs:              ['AAPL', 'IBM']
# shorts:              []
# temp: after transaction++++++++++++
#             AAPL     IBM  GOOG  XOM      cash
# 2011-12-27  20.0  2200.0   0.0  0.0  708602.8
# temp[longs]
#             AAPL     IBM
# 2011-12-27  20.0  2200.0
# prices[longs]
#               AAPL     IBM
# 2011-12-27  404.79  182.68
# Product
#               AAPL       IBM
# 2011-12-27  8095.8  401896.0
# Sum
# AAPL      8095.8
# IBM     401896.0
# dtype: float64
# temp[cash]
# 2011-12-27    708602.8
# Name: cash, dtype: float64
# leverage: xxxxxxxxxxxxxxxxx
# 0.0112959617892
#
#
#
# before transaction------------
# temp
#             AAPL     IBM  GOOG  XOM      cash
# 2011-12-28  20.0  2200.0   0.0  0.0  708602.8
# price
#                SPY    AAPL     IBM   GOOG    XOM
# 2011-12-28  123.64  400.92  181.74  639.7  82.61
# orders
#            Symbol Order  Shares
# Date
# 2011-12-28    IBM  SELL    2200
# longs:              ['AAPL']
# shorts:              []
# temp: after transaction++++++++++++
#             AAPL  IBM  GOOG  XOM       cash
# 2011-12-28  20.0  0.0   0.0  0.0  1108430.8
# temp[longs]
#             AAPL
# 2011-12-28  20.0
# prices[longs]
#               AAPL
# 2011-12-28  400.92
# Product
#               AAPL
# 2011-12-28  8018.4
# Sum
# AAPL    8018.4
# dtype: float64
# temp[cash]
# 2011-12-28    1108430.8
# Name: cash, dtype: float64
# leverage: xxxxxxxxxxxxxxxxx
# 0.00718205539491
#
#
#
# ['AAPL', 'IBM', 'GOOG', 'XOM']
#               AAPL     IBM    GOOG  XOM
# 2011-01-10  1500.0     0.0     0.0  0.0
# 2011-01-11  1500.0     0.0     0.0  0.0
# 2011-01-12  1500.0     0.0     0.0  0.0
# 2011-01-13     0.0  4000.0     0.0  0.0
# 2011-01-14     0.0  4000.0     0.0  0.0
# 2011-01-18     0.0  4000.0     0.0  0.0
# 2011-01-19     0.0  4000.0     0.0  0.0
# 2011-01-20     0.0  4000.0     0.0  0.0
# 2011-01-21     0.0  4000.0     0.0  0.0
# 2011-01-24     0.0  4000.0     0.0  0.0
# 2011-01-25     0.0  4000.0     0.0  0.0
# 2011-01-26     0.0  4000.0  1000.0  0.0
# 2011-01-27     0.0  4000.0  1000.0  0.0
# 2011-01-28     0.0  4000.0  1000.0  0.0
# 2011-01-31     0.0  4000.0  1000.0  0.0
# 2011-02-01     0.0  4000.0  1000.0  0.0
# 2011-02-02     0.0  4000.0  1000.0  0.0
# 2011-02-03     0.0  4000.0  1000.0  0.0
# 2011-02-04     0.0  4000.0  1000.0  0.0
# 2011-02-07     0.0  4000.0  1000.0  0.0
# 2011-02-08     0.0  4000.0  1000.0  0.0
# 2011-02-09     0.0  4000.0  1000.0  0.0
# 2011-02-10     0.0  4000.0  1000.0  0.0
# 2011-02-11     0.0  4000.0  1000.0  0.0
# 2011-02-14     0.0  4000.0  1000.0  0.0
# 2011-02-15     0.0  4000.0  1000.0  0.0
# 2011-02-16     0.0  4000.0  1000.0  0.0
# 2011-02-17     0.0  4000.0  1000.0  0.0
# 2011-02-18     0.0  4000.0  1000.0  0.0
# 2011-02-22     0.0  4000.0  1000.0  0.0
# ...            ...     ...     ...  ...
# 2011-11-15  1200.0  2200.0 -2200.0  0.0
# 2011-11-16  1200.0  2200.0 -2200.0  0.0
# 2011-11-17  1200.0  2200.0 -2200.0  0.0
# 2011-11-18  1200.0  2200.0 -2200.0  0.0
# 2011-11-21  1200.0  2200.0 -2200.0  0.0
# 2011-11-22  1200.0  2200.0 -2200.0  0.0
# 2011-11-23  1200.0  2200.0 -2200.0  0.0
# 2011-11-25  1200.0  2200.0 -2200.0  0.0
# 2011-11-28  1200.0  2200.0 -2200.0  0.0
# 2011-11-29  1200.0  2200.0 -2200.0  0.0
# 2011-11-30  1200.0  2200.0 -2200.0  0.0
# 2011-12-01  1200.0  2200.0 -2200.0  0.0
# 2011-12-02  1200.0  2200.0 -2200.0  0.0
# 2011-12-05  1200.0  2200.0 -2200.0  0.0
# 2011-12-06  1200.0  2200.0 -2200.0  0.0
# 2011-12-07  1200.0  2200.0 -2200.0  0.0
# 2011-12-08  1200.0  2200.0 -2200.0  0.0
# 2011-12-09  1200.0  2200.0 -2200.0  0.0
# 2011-12-12  1200.0  2200.0 -2200.0  0.0
# 2011-12-13  1200.0  2200.0 -2200.0  0.0
# 2011-12-14  1200.0  2200.0 -2200.0  0.0
# 2011-12-15  1200.0  2200.0 -2200.0  0.0
# 2011-12-16  1200.0  2200.0 -2200.0  0.0
# 2011-12-19  1200.0  2200.0 -2200.0  0.0
# 2011-12-20     0.0  2200.0 -2200.0  0.0
# 2011-12-21    20.0  2200.0 -2200.0  0.0
# 2011-12-22    20.0  2200.0 -2200.0  0.0
# 2011-12-23    20.0  2200.0 -2200.0  0.0
# 2011-12-27    20.0  2200.0     0.0  0.0
# 2011-12-28    20.0     0.0     0.0  0.0
#
# [245 rows x 4 columns]
# ============================================================================
#               AAPL     IBM    GOOG    XOM
# 2011-01-10  340.99  143.41  614.21  72.02
# 2011-01-11  340.18  143.06  616.01  72.56
# 2011-01-12  342.95  144.82  616.87  73.41
# 2011-01-13  344.20  144.55  616.69  73.54
# 2011-01-14  346.99  145.70  624.18  74.62
# 2011-01-18  339.19  146.33  639.63  75.45
# 2011-01-19  337.39  151.22  631.75  75.00
# 2011-01-20  331.26  151.33  626.77  74.53
# 2011-01-21  325.32  151.04  611.83  75.71
# 2011-01-24  336.01  155.05  611.08  75.34
# 2011-01-25  339.94  156.81  619.91  75.43
# 2011-01-26  342.38  156.42  616.50  76.37
# 2011-01-27  341.74  156.45  616.79  76.58
# 2011-01-28  334.66  154.64  600.99  75.72
# 2011-01-31  337.87  157.35  600.36  77.34
# 2011-02-01  343.55  158.87  611.04  80.44
# 2011-02-02  342.85  158.62  612.00  79.96
# 2011-02-03  341.97  158.84  610.15  79.99
# 2011-02-04  345.02  159.30  610.98  79.84
# 2011-02-07  350.38  160.09  614.29  80.46
# 2011-02-08  353.68  161.93  618.38  79.97
# 2011-02-09  356.63  160.56  616.50  79.55
# 2011-02-10  353.02  160.02  616.44  80.18
# 2011-02-11  355.32  159.78  624.50  79.81
# 2011-02-14  357.64  159.17  628.15  81.83
# 2011-02-15  358.36  158.80  624.15  79.96
# 2011-02-16  361.58  159.34  624.22  80.65
# 2011-02-17  356.77  160.16  625.26  80.83
# 2011-02-18  349.06  160.75  630.08  81.43
# 2011-02-22  337.16  157.93  610.21  82.34
# ...            ...     ...     ...    ...
# 2011-11-15  387.17  186.44  616.56  77.62
# 2011-11-16  383.13  184.33  611.47  76.79
# 2011-11-17  375.80  183.45  600.87  76.41
# 2011-11-18  373.34  182.97  594.88  76.45
# 2011-11-21  367.43  179.26  580.94  75.48
# 2011-11-22  374.90  179.09  580.00  74.61
# 2011-11-23  365.42  175.77  570.11  73.19
# 2011-11-25  362.02  174.89  563.00  72.52
# 2011-11-28  374.51  179.98  588.19  74.43
# 2011-11-29  371.60  178.72  582.93  75.50
# 2011-11-30  380.57  185.70  599.39  78.94
# 2011-12-01  386.27  187.13  613.77  78.30
# 2011-12-02  388.03  187.34  620.36  78.30
# 2011-12-05  391.33  188.50  625.65  78.95
# 2011-12-06  389.28  190.58  623.77  79.31
# 2011-12-07  387.43  191.67  623.39  79.57
# 2011-12-08  388.99  189.23  616.05  78.38
# 2011-12-09  391.94  192.18  627.42  79.82
# 2011-12-12  390.16  189.83  625.39  78.56
# 2011-12-13  387.15  188.81  625.63  79.03
# 2011-12-14  378.56  186.41  618.07  77.96
# 2011-12-15  377.32  185.18  619.54  78.54
# 2011-12-16  379.39  181.32  625.96  78.67
# 2011-12-19  380.58  180.65  621.83  78.05
# 2011-12-20  394.26  184.95  630.37  80.47
# 2011-12-21  394.76  179.25  625.82  81.57
# 2011-12-22  396.85  179.81  629.70  82.72
# 2011-12-23  401.61  182.49  633.14  83.63
# 2011-12-27  404.79  182.68  640.25  83.69
# 2011-12-28  400.92  181.74  639.70  82.61
#
# [245 rows x 4 columns]

# %%
# Out:
# 240

# %%
c

# %%
"""MC2-P1: Market simulator."""

import pandas as pd
import numpy as np
import datetime as dt
import os
from math import *
from analysis import assess_portfolio 
from util import get_data, plot_data

class MarketsimTestCase(object):
    def __init__(self, description, group, inputs, outputs):
        self.description = description
        self.group = group 
        self.inputs = inputs 
        self.outputs = outputs 
        
marketsim_test_cases = [
    MarketsimTestCase(
        description="Orders 1",
        group='basic',
        inputs=dict(
            orders_file=os.path.join('orders', 'orders-01.csv'),
            start_val=1000000
        ),
        outputs=dict(
            num_days = 245 ,
            last_day_portval = 1115569.2 ,
            sharpe_ratio = 0.612340613407 ,
            avg_daily_ret = 0.00055037432146
        )
    ),
    MarketsimTestCase(
        description="Orders 2",
        group='basic',
        inputs=dict(
            orders_file=os.path.join('orders', 'orders-02.csv'),
            start_val=1000000
        ),
        outputs=dict(
            num_days = 245 ,
            last_day_portval = 1095003.35 ,
            sharpe_ratio = 1.01613520942 ,
            avg_daily_ret = 0.000390534819609
        )
    ),
    MarketsimTestCase(
        description="Orders 3",
        group='basic',
        inputs=dict(
            orders_file=os.path.join('orders', 'orders-03.csv'),
            start_val=1000000
        ),
        outputs=dict(
            num_days = 240 ,
            last_day_portval = 857616.0 ,
            sharpe_ratio = -0.759896272199 ,
            avg_daily_ret = -0.000571326189931
        )
    ),
    MarketsimTestCase(
        description="Orders 4",
        group='basic',
        inputs=dict(
            orders_file=os.path.join('orders', 'orders-04.csv'),
            start_val=1000000
        ),
        outputs=dict(
            num_days = 233 ,
            last_day_portval = 923545.4 ,
            sharpe_ratio = -0.266030146916 ,
            avg_daily_ret =  -0.000240200768212
        )
    ),
    MarketsimTestCase(
        description="Orders 5",
        group='basic',
        inputs=dict(
            orders_file=os.path.join('orders', 'orders-05.csv'),
            start_val=1000000
        ),
        outputs=dict(
            num_days = 296 ,
            last_day_portval = 1415563.0 ,
            sharpe_ratio = 2.19591520826 ,
            avg_daily_ret = 0.00121733290744
        )
    ),
    MarketsimTestCase(
        description="Orders 6",
        group='basic',
        inputs=dict(
            orders_file=os.path.join('orders', 'orders-06.csv'),
            start_val=1000000
        ),
        outputs=dict(
            num_days = 210 ,
            last_day_portval = 894604.3 ,
            sharpe_ratio = -1.23463930987,
            avg_daily_ret =  -0.000511281541086
        )
    ),
    MarketsimTestCase(
        description="Orders 7 (modified)",
        group='basic',
        inputs=dict(
            orders_file=os.path.join('orders', 'orders-07-modified.csv'),
            start_val=1000000
        ),
        outputs=dict(
            num_days = 237 ,
            last_day_portval = 1104930.8 ,
            sharpe_ratio = 2.07335994413 ,
            avg_daily_ret = 0.000428245010481
        )
    ),
    MarketsimTestCase(
        description="Orders 8 (modified)",
        group='basic',
        inputs=dict(
            orders_file=os.path.join('orders', 'orders-08-modified.csv'),
            start_val=1000000
        ),
        outputs=dict(
            num_days = 229 ,
            last_day_portval = 1071325.1 ,
            sharpe_ratio =  0.896734443277,
            avg_daily_ret = 0.000318004442115
        )
    ),
    MarketsimTestCase(
        description="Orders 9 (modified)",
        group='basic',
        inputs=dict(
            orders_file=os.path.join('orders', 'orders-09-modified.csv'),
            start_val=1000000
        ),
        outputs=dict(
            num_days = 37 ,
            last_day_portval = 1058990.0,
            sharpe_ratio = 2.54864656282 ,
            avg_daily_ret = 0.00164458341408
        )
    ),
    MarketsimTestCase(
        description="Orders 10 (modified)",
        group='basic',
        inputs=dict(
            orders_file=os.path.join('orders', 'orders-10-modified.csv'),
            start_val=1000000
        ),
        outputs=dict(
            num_days = 141 ,
            last_day_portval = 1070819.0,
            sharpe_ratio = 1.0145855303,
            avg_daily_ret =  0.000521814978394
        )
    ),
    MarketsimTestCase(
        description="Orders 11 - Leveraged SELL (modified)",
        group='leverage',
        inputs=dict(
            orders_file=os.path.join('orders', 'orders-11-modified.csv'),
            start_val=1000000
        ),
        outputs=dict(
            last_day_portval = 1053560.0
        )
    ),
    MarketsimTestCase(
        description="Orders 12 - Leveraged BUY (modified)",
        group='leverage',
        inputs=dict(
            orders_file=os.path.join('orders', 'orders-12-modified.csv'),
            start_val=1000000
        ),
        outputs=dict(
            last_day_portval = 1044437.0
        )
    ),
    MarketsimTestCase(
        description="Wiki leverage example #1",
        group='leverage',
        inputs=dict(
            orders_file=os.path.join('orders', 'orders-leverage-1.csv'),
            start_val=1000000
        ),
        outputs=dict(
            last_day_portval = 1050160.0
        )
    ),
    MarketsimTestCase(
        description="Wiki leverage example #2",
        group='leverage',
        inputs=dict(
            orders_file=os.path.join('orders', 'orders-leverage-2.csv'),
            start_val=1000000
        ),
        outputs=dict(
            last_day_portval = 1074650.0
        )
    ),
    MarketsimTestCase(
        description="Wiki leverage example #3",
        group='leverage',
        inputs=dict(
            orders_file=os.path.join('orders', 'orders-leverage-3.csv'),
            start_val=1000000
        ),
        outputs=dict(
            last_day_portval = 1050160.0
        )
    ),
]

def compute_portvals(orders_file = "./orders/orders.csv", start_val = 1000000):
    orders_df = pd.read_csv(orders_file, index_col='Date', parse_dates=True, na_values=['nan'])
    orders_df = orders_df.sort_index()
    orderdates = orders_df.index.unique()
    start_date = orders_df.index[0] 
    end_date = orders_df.index[-1]
    symbols = orders_df['Symbol'].unique().tolist()
    dates = pd.date_range(start_date, end_date)
    prices = get_data(symbols, dates)
    #print "##########Days in price:     ", len(prices.index)
    #plot_data(prices)
    symbols.append('cash')
    portvals = pd.DataFrame(data = np.zeros((prices.index.size, len(symbols))), index = prices.index, columns=symbols)
    #print "##########Days in portvals:     ", len(portvals.index)
    #plot_data(portvals)
    DATES = prices.index.to_datetime()
    portvals['cash'] = start_val 
    for i, odate in enumerate(orderdates):
        orders = orders_df[odate:odate]
        temp = portvals[odate:odate].copy()
        #print "temp: before transaction------------"
        #print temp
        #print 
        for j in range(orders.shape[0]):
            if orders.ix[j]['Order'] == 'BUY':
                temp[orders.ix[j]['Symbol']] += orders.ix[j]['Shares']
                temp['cash'] -= orders.ix[j]['Shares'] * prices.ix[odate][orders.ix[j]['Symbol']]
            else:
                temp[orders.ix[j]['Symbol']] -= orders.ix[j]['Shares']
                temp['cash'] += orders.ix[j]['Shares'] * prices.ix[odate][orders.ix[j]['Symbol']]
            longs = temp.ix[0][np.where(temp.ix[0] > 0)[0]].keys().tolist()
            if 'cash' in longs:
                longs.remove('cash')
            shorts = temp.ix[0][np.where(temp.ix[0] < 0)[0]].keys().tolist()
            if 'cash' in shorts:
                shorts.remove('cash')
        #print "temp: after transaction++++++++++++"
        #print temp
        #print 

        if len(longs) > 0:
            #longsum = np.sum(prices[odate:odate][longs]*temp[longs]).values[0]
            longsum = (prices[odate:odate][longs]*temp[longs]).sum(axis = 'columns')
        else:
            longsum = 0
        if len(shorts) > 0:
            #shortsum = np.abs(np.sum(prices[odate:odate][shorts]*temp[shorts])).values[0]
            shortsum = (prices[odate:odate][shorts]*temp[shorts]).sum(axis = 'columns')
        else:
            shortsum = 0
        leverage = (longsum + shortsum)/(longsum - shortsum + temp['cash'].values[0] ) 
        if isinstance(leverage, pd.Series):
            leverage = leverage.ix[0]
        #print "leverage: xxxxxxxxxxxxxxxxx"
        #print leverage
        #print 
        #print 
        #print 


        if leverage <= 2.0:
            td = np.where(DATES >= orderdates[i])[0].size
            portvals[orderdates[i]:] = np.repeat(temp.values, td, axis = 0 ) 
        #td = np.where(DATES >= orderdates[i])[0].size
        #portvals[orderdates[i]:] = np.repeat(temp.values, td, axis = 0 ) 
    #End for loop
    symbols.remove('cash')
    #print symbols
    #plot_data(portvals[symbols])
    #plot_data(prices[symbols])
    #print portvals[symbols]
    #print "============================================================================"
    #print prices[symbols]
    tv = np.sum(portvals[symbols]*prices[symbols], axis = 1) + portvals['cash']
    #plot_data(tv)
    return tv

def assess_port(port_val, sf=252.0, rfr = 0.0):
   
    rdr = port_val[1:]/port_val.values[:-1] - 1
    cr = port_val.values/port_val.values[0] 
    adr = rdr.mean()
    sddr = rdr.std()
    sr = (adr -rfr)/sddr*np.sqrt(sf)
    
    return (cr-1)[-1],adr,sddr,sr, port_val[-1]
    


def test_code():
    # this is a helper function you can use to test your code
    # note that during autograding his function will not be called.
    # Define input parameters

    of = "./orders/orders.csv"
    startv = 1000000

    # Process orders
    portvals = compute_portvals(orders_file = of, start_val = startv)
    if isinstance(portvals, pd.DataFrame):
        portvals = portvals[portvals.columns[0]] # just get the first column
    else:
        "warning, code did not return a DataFrame"
    
    # Get portfolio stats
    # Here we just fake the data. you should use your code from previous assignments.
    
    cum_ret, avg_daily_ret, std_daily_ret, sharpe_ratio,_ = assess_port(portvals)
    
    start_date = portvals.index.to_datetime()[0]
    end_date = portvals.index.to_datetime()[-1]
    cum_ret_SPY, avg_daily_ret_SPY, std_daily_ret_SPY, sharpe_ratio_SPY, _ = \
    assess_portfolio(sd = start_date, ed = end_date, syms = ['SPY'],allocs = [1.0],\
                    sv = startv)

    # Compare portfolio against $SPX
    print "Date Range: {} to {}".format(start_date, end_date)
    print
    print "Sharpe Ratio of Fund: {}".format(sharpe_ratio)
    print "Sharpe Ratio of SPY : {}".format(sharpe_ratio_SPY)
    print
    print "Cumulative Return of Fund: {}".format(cum_ret)
    print "Cumulative Return of SPY : {}".format(cum_ret_SPY)
    print
    print "Standard Deviation of Fund: {}".format(std_daily_ret)
    print "Standard Deviation of SPY : {}".format(std_daily_ret_SPY)
    print
    print "Average Daily Return of Fund: {}".format(avg_daily_ret)
    print "Average Daily Return of SPY : {}".format(avg_daily_ret_SPY)
    print
    print "Final Portfolio Value: {}".format(portvals[-1])

def runtestcases(cases):
    errors = []
    for case in cases:
        of, sv = case.inputs['orders_file'], case.inputs['start_val']
        print case.description, ':  ', of
        pv = compute_portvals(of, sv)
        num_days = len(pv.index)
        cr, adr, sddr, sr, ev = assess_port(pv)
        err = []
        if case.group == 'basic':
            print "Error in number of days",\
            np.abs(num_days - case.outputs['num_days'])/case.outputs['num_days'] 
            err.append(np.abs(num_days - case.outputs['num_days'])/case.outputs['num_days'])
            print "Error in last day value: ", \
            np.abs(ev - case.outputs['last_day_portval'])/case.outputs['last_day_portval']
            err.append(np.abs(ev - case.outputs['last_day_portval'])/case.outputs['last_day_portval'])
            print "Error in sharpe ratio",\
            np.abs(sr - case.outputs['sharpe_ratio'])/case.outputs['sharpe_ratio']
            err.append(np.abs(sr - case.outputs['sharpe_ratio'])/case.outputs['sharpe_ratio'])
            print "Error in average daily return",\
            np.abs(adr - case.outputs['avg_daily_ret'])/case.outputs['avg_daily_ret']
            err.append(np.abs(adr - case.outputs['avg_daily_ret'])/case.outputs['avg_daily_ret'])
            print '----------------------------------------------------------'
            print 
        else:
            print "Error in last day value: ", \
            np.abs(ev - case.outputs['last_day_portval'])/case.outputs['last_day_portval']
            print '----------------------------------------------------------'
            print
            err.append(np.abs(ev - case.outputs['last_day_portval'])/case.outputs['last_day_portval'])
        errors.append(np.array(err))
    return errors
        
    
if __name__ == "__main__":
    test_code()
    errors = runtestcases(marketsim_test_cases)
    print '=============TEST CASE ERRORS===================='
    print errors
# Out:
# Date Range: 2011-01-10 00:00:00 to 2011-12-20 00:00:00
#
# Sharpe Ratio of Fund: 1.21540888742
# Sharpe Ratio of SPY : 0.101537802693
#
# Cumulative Return of Fund: 0.13386
# Cumulative Return of SPY : -0.00357171848364
#
# Standard Deviation of Fund: 0.00720514136323
# Standard Deviation of SPY : 0.0148094637491
#
# Average Daily Return of Fund: 0.000551651296638
# Average Daily Return of SPY : 9.47254819364e-05
#
# Final Portfolio Value: 1133860.0
# Orders 1 :   orders/orders-01.csv
# Error in number of days 0
# Error in last day value:  2.08710175625e-16
# Error in sharpe ratio 7.86877078113e-13
# Error in average daily return 7.69456989653e-13
# ----------------------------------------------------------
#
# Orders 2 :   orders/orders-02.csv
# Error in number of days 0
# Error in last day value:  0.0
# Error in sharpe ratio 9.59297351951e-14
# Error in average daily return 3.56880314571e-13
# ----------------------------------------------------------
#
# Orders 3 :   orders/orders-03.csv
# Error in number of days 0
# Error in last day value:  2.71485890718e-16
# Error in sharpe ratio -1.92416225336e-13
# Error in average daily return -4.9738554685e-13
# ----------------------------------------------------------
#
# Orders 4 :   orders/orders-04.csv
# Error in number of days 0
# Error in last day value:  1.26052624838e-16
# Error in sharpe ratio -2.29531378538e-13
# Error in average daily return -6.85184693656e-13
# ----------------------------------------------------------
#
# Orders 5 :   orders/orders-05.csv
# Error in number of days 0
# Error in last day value:  0.0
# Error in sharpe ratio 1.02330517744e-12
# Error in average daily return 3.11509324632e-12
# ----------------------------------------------------------
#
# Orders 6 :   orders/orders-06.csv
# Error in number of days 0
# Error in last day value:  0.0
# Error in sharpe ratio -2.6800610317e-12
# Error in average daily return -8.48223208045e-16
# ----------------------------------------------------------
#
# Orders 7 (modified) :   orders/orders-07-modified.csv
# Error in number of days 0
# Error in last day value:  2.10719661045e-16
# Error in sharpe ratio 7.08962902831e-13
# Error in average daily return 2.70515707819e-13
# ----------------------------------------------------------
#
# Orders 8 (modified) :   orders/orders-08-modified.csv
# Error in number of days 0
# Error in last day value:  2.17329588986e-16
# Error in sharpe ratio 4.72448793925e-13
# Error in average daily return 1.41796661876e-12
# ----------------------------------------------------------
#
# Orders 9 (modified) :   orders/orders-09-modified.csv
# Error in number of days 0
# Error in last day value:  0.0
# Error in sharpe ratio 1.55705433508e-12
# Error in average daily return 5.4797393556e-13
# ----------------------------------------------------------
#
# Orders 10 (modified) :   orders/orders-10-modified.csv
# Error in number of days 0
# Error in last day value:  0.0
# Error in sharpe ratio 1.86068416579e-12
# Error in average daily return 1.39209391383e-13
# ----------------------------------------------------------
#
# Orders 11 - Leveraged SELL (modified) :   orders/orders-11-modified.csv
# Error in last day value:  0.0
# ----------------------------------------------------------
#
# Orders 12 - Leveraged BUY (modified) :   orders/orders-12-modified.csv
# Error in last day value:  0.0
# ----------------------------------------------------------
#
# Wiki leverage example #1 :   orders/orders-leverage-1.csv
# Error in last day value:  0.0
# ----------------------------------------------------------
#
# Wiki leverage example #2 :   orders/orders-leverage-2.csv
# Error in last day value:  0.0
# ----------------------------------------------------------
#
# Wiki leverage example #3 :   orders/orders-leverage-3.csv
# Error in last day value:  0.0
# ----------------------------------------------------------
#
# =============TEST CASE ERRORS====================
# [array([  0.00000000e+00,   2.08710176e-16,   7.86877078e-13,
#          7.69456990e-13]), array([  0.00000000e+00,   0.00000000e+00,   9.59297352e-14,
#          3.56880315e-13]), array([  0.00000000e+00,   2.71485891e-16,  -1.92416225e-13,
#         -4.97385547e-13]), array([  0.00000000e+00,   1.26052625e-16,  -2.29531379e-13,
#         -6.85184694e-13]), array([  0.00000000e+00,   0.00000000e+00,   1.02330518e-12,
#          3.11509325e-12]), array([  0.00000000e+00,   0.00000000e+00,  -2.68006103e-12,
#         -8.48223208e-16]), array([  0.00000000e+00,   2.10719661e-16,   7.08962903e-13,
#          2.70515708e-13]), array([  0.00000000e+00,   2.17329589e-16,   4.72448794e-13,
#          1.41796662e-12]), array([  0.00000000e+00,   0.00000000e+00,   1.55705434e-12,
#          5.47973936e-13]), array([  0.00000000e+00,   0.00000000e+00,   1.86068417e-12,
#          1.39209391e-13]), array([ 0.]), array([ 0.]), array([ 0.]), array([ 0.]), array([ 0.])]

# %%
# %save marketsim.py _ih[46]
# Out:
# File `marketsim.py` exists. Overwrite (y/[N])?  y
# The following commands were written to file `marketsim.py`:
# """MC2-P1: Market simulator."""
#
# import pandas as pd
# import numpy as np
# import datetime as dt
# import os
# from math import *
# from analysis import assess_portfolio
# from util import get_data, plot_data
#
# class MarketsimTestCase(object):
#     def __init__(self, description, group, inputs, outputs):
#         self.description = description
#         self.group = group
#         self.inputs = inputs
#         self.outputs = outputs
#
# marketsim_test_cases = [
#     MarketsimTestCase(
#         description="Orders 1",
#         group='basic',
#         inputs=dict(
#             orders_file=os.path.join('orders', 'orders-01.csv'),
#             start_val=1000000
#         ),
#         outputs=dict(
#             num_days = 245 ,
#             last_day_portval = 1115569.2 ,
#             sharpe_ratio = 0.612340613407 ,
#             avg_daily_ret = 0.00055037432146
#         )
#     ),
#     MarketsimTestCase(
#         description="Orders 2",
#         group='basic',
#         inputs=dict(
#             orders_file=os.path.join('orders', 'orders-02.csv'),
#             start_val=1000000
#         ),
#         outputs=dict(
#             num_days = 245 ,
#             last_day_portval = 1095003.35 ,
#             sharpe_ratio = 1.01613520942 ,
#             avg_daily_ret = 0.000390534819609
#         )
#     ),
#     MarketsimTestCase(
#         description="Orders 3",
#         group='basic',
#         inputs=dict(
#             orders_file=os.path.join('orders', 'orders-03.csv'),
#             start_val=1000000
#         ),
#         outputs=dict(
#             num_days = 240 ,
#             last_day_portval = 857616.0 ,
#             sharpe_ratio = -0.759896272199 ,
#             avg_daily_ret = -0.000571326189931
#         )
#     ),
#     MarketsimTestCase(
#         description="Orders 4",
#         group='basic',
#         inputs=dict(
#             orders_file=os.path.join('orders', 'orders-04.csv'),
#             start_val=1000000
#         ),
#         outputs=dict(
#             num_days = 233 ,
#             last_day_portval = 923545.4 ,
#             sharpe_ratio = -0.266030146916 ,
#             avg_daily_ret =  -0.000240200768212
#         )
#     ),
#     MarketsimTestCase(
#         description="Orders 5",
#         group='basic',
#         inputs=dict(
#             orders_file=os.path.join('orders', 'orders-05.csv'),
#             start_val=1000000
#         ),
#         outputs=dict(
#             num_days = 296 ,
#             last_day_portval = 1415563.0 ,
#             sharpe_ratio = 2.19591520826 ,
#             avg_daily_ret = 0.00121733290744
#         )
#     ),
#     MarketsimTestCase(
#         description="Orders 6",
#         group='basic',
#         inputs=dict(
#             orders_file=os.path.join('orders', 'orders-06.csv'),
#             start_val=1000000
#         ),
#         outputs=dict(
#             num_days = 210 ,
#             last_day_portval = 894604.3 ,
#             sharpe_ratio = -1.23463930987,
#             avg_daily_ret =  -0.000511281541086
#         )
#     ),
#     MarketsimTestCase(
#         description="Orders 7 (modified)",
#         group='basic',
#         inputs=dict(
#             orders_file=os.path.join('orders', 'orders-07-modified.csv'),
#             start_val=1000000
#         ),
#         outputs=dict(
#             num_days = 237 ,
#             last_day_portval = 1104930.8 ,
#             sharpe_ratio = 2.07335994413 ,
#             avg_daily_ret = 0.000428245010481
#         )
#     ),
#     MarketsimTestCase(
#         description="Orders 8 (modified)",
#         group='basic',
#         inputs=dict(
#             orders_file=os.path.join('orders', 'orders-08-modified.csv'),
#             start_val=1000000
#         ),
#         outputs=dict(
#             num_days = 229 ,
#             last_day_portval = 1071325.1 ,
#             sharpe_ratio =  0.896734443277,
#             avg_daily_ret = 0.000318004442115
#         )
#     ),
#     MarketsimTestCase(
#         description="Orders 9 (modified)",
#         group='basic',
#         inputs=dict(
#             orders_file=os.path.join('orders', 'orders-09-modified.csv'),
#             start_val=1000000
#         ),
#         outputs=dict(
#             num_days = 37 ,
#             last_day_portval = 1058990.0,
#             sharpe_ratio = 2.54864656282 ,
#             avg_daily_ret = 0.00164458341408
#         )
#     ),
#     MarketsimTestCase(
#         description="Orders 10 (modified)",
#         group='basic',
#         inputs=dict(
#             orders_file=os.path.join('orders', 'orders-10-modified.csv'),
#             start_val=1000000
#         ),
#         outputs=dict(
#             num_days = 141 ,
#             last_day_portval = 1070819.0,
#             sharpe_ratio = 1.0145855303,
#             avg_daily_ret =  0.000521814978394
#         )
#     ),
#     MarketsimTestCase(
#         description="Orders 11 - Leveraged SELL (modified)",
#         group='leverage',
#         inputs=dict(
#             orders_file=os.path.join('orders', 'orders-11-modified.csv'),
#             start_val=1000000
#         ),
#         outputs=dict(
#             last_day_portval = 1053560.0
#         )
#     ),
#     MarketsimTestCase(
#         description="Orders 12 - Leveraged BUY (modified)",
#         group='leverage',
#         inputs=dict(
#             orders_file=os.path.join('orders', 'orders-12-modified.csv'),
#             start_val=1000000
#         ),
#         outputs=dict(
#             last_day_portval = 1044437.0
#         )
#     ),
#     MarketsimTestCase(
#         description="Wiki leverage example #1",
#         group='leverage',
#         inputs=dict(
#             orders_file=os.path.join('orders', 'orders-leverage-1.csv'),
#             start_val=1000000
#         ),
#         outputs=dict(
#             last_day_portval = 1050160.0
#         )
#     ),
#     MarketsimTestCase(
#         description="Wiki leverage example #2",
#         group='leverage',
#         inputs=dict(
#             orders_file=os.path.join('orders', 'orders-leverage-2.csv'),
#             start_val=1000000
#         ),
#         outputs=dict(
#             last_day_portval = 1074650.0
#         )
#     ),
#     MarketsimTestCase(
#         description="Wiki leverage example #3",
#         group='leverage',
#         inputs=dict(
#             orders_file=os.path.join('orders', 'orders-leverage-3.csv'),
#             start_val=1000000
#         ),
#         outputs=dict(
#             last_day_portval = 1050160.0
#         )
#     ),
# ]
#
# def compute_portvals(orders_file = "./orders/orders.csv", start_val = 1000000):
#     orders_df = pd.read_csv(orders_file, index_col='Date', parse_dates=True, na_values=['nan'])
#     orders_df = orders_df.sort_index()
#     orderdates = orders_df.index.unique()
#     start_date = orders_df.index[0]
#     end_date = orders_df.index[-1]
#     symbols = orders_df['Symbol'].unique().tolist()
#     dates = pd.date_range(start_date, end_date)
#     prices = get_data(symbols, dates)
#     #print "##########Days in price:     ", len(prices.index)
#     #plot_data(prices)
#     symbols.append('cash')
#     portvals = pd.DataFrame(data = np.zeros((prices.index.size, len(symbols))), index = prices.index, columns=symbols)
#     #print "##########Days in portvals:     ", len(portvals.index)
#     #plot_data(portvals)
#     DATES = prices.index.to_datetime()
#     portvals['cash'] = start_val
#     for i, odate in enumerate(orderdates):
#         orders = orders_df[odate:odate]
#         temp = portvals[odate:odate].copy()
#         #print "temp: before transaction------------"
#         #print temp
#         #print
#         for j in range(orders.shape[0]):
#             if orders.ix[j]['Order'] == 'BUY':
#                 temp[orders.ix[j]['Symbol']] += orders.ix[j]['Shares']
#                 temp['cash'] -= orders.ix[j]['Shares'] * prices.ix[odate][orders.ix[j]['Symbol']]
#             else:
#                 temp[orders.ix[j]['Symbol']] -= orders.ix[j]['Shares']
#                 temp['cash'] += orders.ix[j]['Shares'] * prices.ix[odate][orders.ix[j]['Symbol']]
#             longs = temp.ix[0][np.where(temp.ix[0] > 0)[0]].keys().tolist()
#             if 'cash' in longs:
#                 longs.remove('cash')
#             shorts = temp.ix[0][np.where(temp.ix[0] < 0)[0]].keys().tolist()
#             if 'cash' in shorts:
#                 shorts.remove('cash')
#         #print "temp: after transaction++++++++++++"
#         #print temp
#         #print
#
#         if len(longs) > 0:
#             #longsum = np.sum(prices[odate:odate][longs]*temp[longs]).values[0]
#             longsum = (prices[odate:odate][longs]*temp[longs]).sum(axis = 'columns')
#         else:
#             longsum = 0
#         if len(shorts) > 0:
#             #shortsum = np.abs(np.sum(prices[odate:odate][shorts]*temp[shorts])).values[0]
#             shortsum = (prices[odate:odate][shorts]*temp[shorts]).sum(axis = 'columns')
#         else:
#             shortsum = 0
#         leverage = (longsum + shortsum)/(longsum - shortsum + temp['cash'].values[0] )
#         if isinstance(leverage, pd.Series):
#             leverage = leverage.ix[0]
#         #print "leverage: xxxxxxxxxxxxxxxxx"
#         #print leverage
#         #print
#         #print
#         #print
#
#
#         if leverage <= 2.0:
#             td = np.where(DATES >= orderdates[i])[0].size
#             portvals[orderdates[i]:] = np.repeat(temp.values, td, axis = 0 )
#         #td = np.where(DATES >= orderdates[i])[0].size
#         #portvals[orderdates[i]:] = np.repeat(temp.values, td, axis = 0 )
#     #End for loop
#     symbols.remove('cash')
#     #print symbols
#     #plot_data(portvals[symbols])
#     #plot_data(prices[symbols])
#     #print portvals[symbols]
#     #print "============================================================================"
#     #print prices[symbols]
#     tv = np.sum(portvals[symbols]*prices[symbols], axis = 1) + portvals['cash']
#     #plot_data(tv)
#     return tv
#
# def assess_port(port_val, sf=252.0, rfr = 0.0):
#
#     rdr = port_val[1:]/port_val.values[:-1] - 1
#     cr = port_val.values/port_val.values[0]
#     adr = rdr.mean()
#     sddr = rdr.std()
#     sr = (adr -rfr)/sddr*np.sqrt(sf)
#
#     return (cr-1)[-1],adr,sddr,sr, port_val[-1]
#
#
#
# def test_code():
#     # this is a helper function you can use to test your code
#     # note that during autograding his function will not be called.
#     # Define input parameters
#
#     of = "./orders/orders.csv"
#     startv = 1000000
#
#     # Process orders
#     portvals = compute_portvals(orders_file = of, start_val = startv)
#     if isinstance(portvals, pd.DataFrame):
#         portvals = portvals[portvals.columns[0]] # just get the first column
#     else:
#         "warning, code did not return a DataFrame"
#
#     # Get portfolio stats
#     # Here we just fake the data. you should use your code from previous assignments.
#
#     cum_ret, avg_daily_ret, std_daily_ret, sharpe_ratio,_ = assess_port(portvals)
#
#     start_date = portvals.index.to_datetime()[0]
#     end_date = portvals.index.to_datetime()[-1]
#     cum_ret_SPY, avg_daily_ret_SPY, std_daily_ret_SPY, sharpe_ratio_SPY, _ =     assess_portfolio(sd = start_date, ed = end_date, syms = ['SPY'],allocs = [1.0],                    sv = startv)
#
#     # Compare portfolio against $SPX
#     print "Date Range: {} to {}".format(start_date, end_date)
#     print
#     print "Sharpe Ratio of Fund: {}".format(sharpe_ratio)
#     print "Sharpe Ratio of SPY : {}".format(sharpe_ratio_SPY)
#     print
#     print "Cumulative Return of Fund: {}".format(cum_ret)
#     print "Cumulative Return of SPY : {}".format(cum_ret_SPY)
#     print
#     print "Standard Deviation of Fund: {}".format(std_daily_ret)
#     print "Standard Deviation of SPY : {}".format(std_daily_ret_SPY)
#     print
#     print "Average Daily Return of Fund: {}".format(avg_daily_ret)
#     print "Average Daily Return of SPY : {}".format(avg_daily_ret_SPY)
#     print
#     print "Final Portfolio Value: {}".format(portvals[-1])
#
# def runtestcases(cases):
#     errors = []
#     for case in cases:
#         of, sv = case.inputs['orders_file'], case.inputs['start_val']
#         print case.description, ':  ', of
#         pv = compute_portvals(of, sv)
#         num_days = len(pv.index)
#         cr, adr, sddr, sr, ev = assess_port(pv)
#         err = []
#         if case.group == 'basic':
#             print "Error in number of days",            np.abs(num_days - case.outputs['num_days'])/case.outputs['num_days']
#             err.append(np.abs(num_days - case.outputs['num_days'])/case.outputs['num_days'])
#             print "Error in last day value: ",             np.abs(ev - case.outputs['last_day_portval'])/case.outputs['last_day_portval']
#             err.append(np.abs(ev - case.outputs['last_day_portval'])/case.outputs['last_day_portval'])
#             print "Error in sharpe ratio",            np.abs(sr - case.outputs['sharpe_ratio'])/case.outputs['sharpe_ratio']
#             err.append(np.abs(sr - case.outputs['sharpe_ratio'])/case.outputs['sharpe_ratio'])
#             print "Error in average daily return",            np.abs(adr - case.outputs['avg_daily_ret'])/case.outputs['avg_daily_ret']
#             err.append(np.abs(adr - case.outputs['avg_daily_ret'])/case.outputs['avg_daily_ret'])
#             print '----------------------------------------------------------'
#             print
#         else:
#             print "Error in last day value: ",             np.abs(ev - case.outputs['last_day_portval'])/case.outputs['last_day_portval']
#             print '----------------------------------------------------------'
#             print
#             err.append(np.abs(ev - case.outputs['last_day_portval'])/case.outputs['last_day_portval'])
#         errors.append(np.array(err))
#     return errors
#
#
# if __name__ == "__main__":
#     test_code()
#     errors = runtestcases(marketsim_test_cases)
#     print '=============TEST CASE ERRORS===================='
#     print errors

# %%
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-21-c07c0223e2dd> in <module>()
# ----> 1 lls
#
# NameError: name 'lls' is not defined
